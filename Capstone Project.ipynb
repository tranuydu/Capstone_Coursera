# %% [markdown]
# <h1>Capstone Project Course Coursera</h1>

# %% [markdown]
# This notebook contains the code for the Coursera Capstone Project on Data Science by IBM and Coursera

# %%
import pandas as pd
import numpy as np

# %%
Hello Capstone Project Course!
